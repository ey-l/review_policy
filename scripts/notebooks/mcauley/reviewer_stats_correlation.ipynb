# %%
import pandas as pd
import numpy as np

# %%
DIR_PATH = '../../../../../Dropbox/Eugenie/data/processed_julian_amazon_data'

# %%
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# ### Total review count vs. other features

# %%
df = pd.read_csv(DIR_PATH+'/reviewer_data/office_products_18months.csv', low_memory=False, index_col=0)
# Out:
# /Users/yujinglai/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#              reviewerID  total_review_count  day_count  brand_count  \
# 0  A0000932YCOC06EWVVQY                   4          2            3
# 1  A0001624UKLQG4OFIM8X                   5          3            4
# 2  A0003492LQH8LJXPWDMZ                  12          6           11
# 3  A0005084YJVVWO39EBAI                   1          1            1
# 4  A0007154ZQMFVTRTSP3X                   2          1            2
#
#    avg_rating  avg_sentiment  avg_word_count  avg_vote  avg_images  \
# 0    5.000000       0.781350      485.250000  3.000000         0.0
# 1    5.000000       0.639400       57.000000  0.000000         0.0
# 2    3.583333       0.542608      111.333333  2.416667         0.0
# 3    5.000000       0.000000       46.000000  0.000000         0.0
# 4    5.000000       0.828600       52.000000  0.000000         0.0
#
#    burstiness  repeated_brands
# 0    2.000000         1.333333
# 1    1.666667         1.250000
# 2    2.000000         1.090909
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.describe()
# Out:
#        total_review_count  day_count  brand_count  avg_rating  avg_sentiment  \
# count          1366717.00 1366717.00   1366717.00  1366717.00     1366232.00
# mean                 7.74       3.57         6.58        4.15           0.46
# std                 11.68       4.83         9.24        1.08           0.34
# min                  1.00       1.00         0.00        1.00          -1.00
# 25%                  2.00       1.00         1.00        3.83           0.31
# 50%                  4.00       2.00         3.00        4.50           0.52
# 75%                  9.00       4.00         8.00        5.00           0.69
# max               1276.00     337.00       421.00        5.00           1.00
#
#        avg_word_count   avg_vote  avg_images  burstiness  repeated_brands
# count      1366717.00 1366717.00  1366717.00  1366717.00       1365633.00
# mean           166.02       0.47        0.02        2.21             1.15
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corrMatrix = df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corrMatrix, annot=True, vmin=-1, vmax=1, center=0,)
plt.show()

# %%
sns.pairplot(df.dropna(), size=2)
